# %% [markdown]
# <p style="background-color:#006D77 ;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>👥 HR Insights: Understanding Workforce Trends through EDA</b></p>
#
#
# <b> Other Platforms </b>[🔵📊Kaggle](https://www.kaggle.com/fatimakiraz) | [🔗💼 LinkedIn](https://www.linkedin.com/in/fatimah-nk-datascientist/) | [🐙💻GitHub](https://github.com/Fay-nk)

# %% [markdown]
# # 🧠 HR EDA & Attrition Analysis
# Welcome to my Human Resources Data Analysis project—an end-to-end EDA performed on a real-world HR dataset consisting of 1,740 employee records. This project was originally developed during my Data Scientist internship and has since been enhanced for portfolio-level quality, with a focus on insight generation, data storytelling, and domain relevance.
#
# ## 🔍 Objectives:
# - Explore patterns behind employee attrition.
# - Understand how satisfaction metrics vary with roles and departments.
# - Investigate salary dynamics, promotion timelines, and work-life balance.
#
# ## 📘 Dataset Overview:
# The dataset includes demographic and work-related features such as age, income, department, job role, years at company, job satisfaction, and attrition status.
#
# ## ✨ Key Features:
# - In-depth statistical and visual exploration
# - Attrition vs retention comparisons
# - Feature engineering for insights like net worth & adjusted salary
# - Correlation and distribution analysis
# - Contextual interpretations relevant to HR stakeholders
#
# ## 🛠️ Tech Stack:
# - Python (Pandas, NumPy, Matplotlib, Seaborn)
# - Jupyter Notebook
# - Markdown for clean documentation
#
# ## 🧩 Ideal Use Cases:
# - Portfolio project for recruiters or hiring managers
# - EDA example for students & HR data enthusiasts
# - Foundation for HR-related thesis or blog posts
#
# Feel free to fork, explore, and contribute!
# 📫 Let’s connect on [LinkedIn](https://www.linkedin.com/in/fatimah-nk-datascientist/)  if you’d like to collaborate or have feedback.

# %% [markdown]
# ### **Dataset Info:**
# The Human Resource dataset has 1740 entries. Each entry contains the following information about an employee:
#
# - **Age:** the employee's age (integer greater than 17).
# - **Monthly Income:** Monthly income of the employee (float, 1009 - 19999 ).
# - **Attrition:** Whether the employee has left the company (Yes/No).
# - **BusinessTravel:** Frequency of business travel (Non-Travel, Travel_Rarely, Travel_Frequently).
# - **DailyRate:** Daily rate of the employee (integer, from 102 till 1499).
# - **Department:** Departmentwhereh the employee works (Sales, Research & Development, etc.).
# - **DistanceFromHome:** Distance from home to work (integer, 1 to 29).
# - **Education:** Education level (integer, categorical, between 1 to 5).
# - **EducationField:** Field of education (Life Sciences, Medical, etc.).
# - **EmployeeCount:** Number of employees, seems to be a constant (integer, 1).
# - **EmployeeNumber:** Unique identifier for the employee (float).
# - **EnvironmentSatisfaction:** Satisfaction with the work environment (integer, categorical, between 1 and 4).
# - **Gender:** Gender of the employee (Male/Female).
# - **HourlyRate:** Hourly rate of the employee (integer, from 30 to 100).
# - **JobInvolvement:** Involvement in the job (integer, categorical, from 1 to 4).
# - **JobLevel:** Job level (integer, categorial, from 1 to 5).
# - **JobRole:** Job role (Sales Executive, Research Scientist, etc.).
# - **JobSatisfaction:** Satisfaction with the job (integer, probably a categorical encoding).
#
# - **Marital Status:** Marital status (Single, Married, Divorced).
# - **MonthlyRate:** Monthly rate (float).
#
# - **NumCompaniesWorked:** Number of companies the employee has worked for (integer).
#
# - **Over18:** Whether the employee is over 18 (Yes/No).
# - **OverTime:** Whether the employee works overtime (Yes/No).
# - **PercentSalaryHike:** Percentage increase in salary (float).
#
# - **PerformanceRating:** Performance rating (float, probably a categorical encoding).
#
# - **RelationshipSatisfaction:** Satisfaction with relationships at work (integer, probably a categorical encoding).
# - **StandardHours:** Standard hours worked (integer, seems constant).
#
#
#
#
#
#
#
# - **StockOptionLevel:** Level of stock options (integer).
#
# - **TotalWorkingYears:** Total number of working years (integer).
#
# - **TrainingTimesLastYear:** Number of training times last year (integer).
#
# - **WorkLifeBalance:** Work-life balance (integer, probably a categorical encoding).
#
# - **YearsAtCompany:** Number of years at the company (integer).
#
# - **YearsInCurrentRole:** Number of years in the current role (integer).
#
# - **YearsSinceLastPromotion:** Number of years since the last promotion (integer).
#
# - **YearsWithCurrManager:** Number of years with the current manager (integer).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Let's read a CSV file using Pandas as follows

# %%
employee_df = pd.read_csv("Human_Resources.csv").copy()

# %% [markdown]
# Let's obtain the datatype

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %% [markdown]
# we can view the first couple of rows using .head()

# %%
employee_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# ...

# %% [markdown]
# we can view the last couple of rows using .tail()

# %%
employee_df.tail()
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# ...

# %% [markdown]
# Calculate the average values for employee_df dataframe

# %%
average_values = employee_df.mean(numeric_only=True)
overall_average = average_values.mean()
overall_average
# Out:
# 881.1259894057827

# %% [markdown]
# 35 features in total

# %%
average_values = employee_df.mean(numeric_only=True)
average_values
# Out:
# Age                            36.923810
# MonthlyIncome                6505.155419
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1025.556161
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyRate                 14310.966621
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.206263
# PerformanceRating               3.153165
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %% [markdown]
# ##### As this is a general overview of the dataset it noticed the following insights:
# 1. **Work Experience:**
#    - The avg. age of employees is approximately 37
#    -  each employee has an avg. of 11 working years, which indicates mid-career professional.
#    -   on avg., each employee has been at their company for 7 years and approximately 4 years in the same role.
#    -    a promotion avg. is approximately every 2 years, which is a good avg. for many employees.
#
# 3. **Salary insight and benefits:**
#    - employees receive an avg. salary hike of 15.21%
#
# 5. **Job Satisfaction:**
#    - The average work-life balance rating is 2.76, indicating employees feel moderately balanced between work and personal life.
#    -  The average environment and relationship satisfaction is approximately 3, suggesting employees are moderately satisfied with their work environment and their relationship with their colleagues.

# %% [markdown]
# Obtain a Statistical Summary about the data

# %%
statistical_summary = employee_df.describe(include='all')
print(statistical_summary)
# Out:
#                 Age  MonthlyIncome Attrition BusinessTravel    DailyRate  \
# count   1470.000000    1467.000000      1470           1470  1470.000000
# unique          NaN            NaN         2              3          NaN
# top             NaN            NaN        No  Travel_Rarely          NaN
# freq            NaN            NaN      1233           1043          NaN
# mean      36.923810    6505.155419       NaN            NaN   802.485714
# std        9.135373    4711.297846       NaN            NaN   403.509100
# min       18.000000    1009.000000       NaN            NaN   102.000000
# 25%       30.000000    2911.000000       NaN            NaN   465.000000
# 50%       36.000000    4908.000000       NaN            NaN   802.000000
# 75%       43.000000    8378.000000       NaN            NaN  1157.000000
# max       60.000000   19999.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# ...

# %%
employee_Age_mean = employee_df.Age.mean()
print ("the employee mean age is:",employee_Age_mean)

employee_Age_max = employee_df.Age.max()
print ("\nthe maximum age of employee is:",employee_Age_max)

employee_Age_min = employee_df.Age.min()
print ("\nthe minimum age employee is:",employee_Age_min)
# Out:
# the employee mean age is: 36.923809523809524
#
# the maximum age of employee is: 60
#
# the minimum age employee is: 18

# %% [markdown]
# ##### The output provides information about the age distribution of employees. Some insights were taken from the results:
# 1. Avg. age:
#    - as the average age is 36.923809523809524, this indicates that this company is mostly primarily of mid-career professionals.
#
# 2. Age range:
#    - The youngest employee is 18 years old, suggesting that the company hires young adults, possibly right out of high school or early in their college years.
#    - The oldest employee is 60 years old, indicating that the company also retains more experienced, older employees who are likely closer to retirement.
#    - The wide range in ages (from 18 to 60) suggests that the company has a diverse age demographic. This diversity can bring a mix of fresh perspectives and seasoned experience to the workplace.
#    - Younger employees might be more focused on career development and growth opportunities, while older employees might prioritize job security and retirement planning.

# %% [markdown]
# #### DEALING WITH MISSING DATA
#
# - Let's locate rows that have Null values

# %%
null_rows = employee_df[employee_df.isnull().any(axis=1)].index

print("Rows with null values (indices):")
print(null_rows)
# Out:
# Rows with null values (indices):
# Index([1, 6, 7, 17, 23, 103, 947], dtype='int64')

# %% [markdown]
# - Notice Row index 6 has many missing values

# %%
row_index_6 = employee_df.iloc[6]

missing_values_count = row_index_6.isnull().sum()

print(f"Details of row at index 6:")
print(row_index_6)
print(f"\nNumber of missing values in row at index 6: {missing_values_count}")
# Out:
# Details of row at index 6:
# Age                                             59
# MonthlyIncome                                  NaN
# Attrition                                       No
# BusinessTravel                       Travel_Rarely
# DailyRate                                     1324
# Department                  Research & Development
# DistanceFromHome                                 3
# Education                                        3
# EducationField                                 NaN
# EmployeeCount                                    1
# EmployeeNumber                                 NaN
# EnvironmentSatisfaction                          3
# Gender                                         NaN
# HourlyRate                                      81
# JobInvolvement                                   4
# JobLevel                                         1
# JobRole                                        NaN
# JobSatisfaction                                  1
# ...

# %% [markdown]
# - Let's see the total number of missing elements per column

# %%
missing_values = {col: employee_df[col].isnull().sum() for col in employee_df.columns}
print(missing_values)
# Out:
# {'Age': 0, 'MonthlyIncome': 3, 'Attrition': 0, 'BusinessTravel': 0, 'DailyRate': 0, 'Department': 1, 'DistanceFromHome': 0, 'Education': 0, 'EducationField': 1, 'EmployeeCount': 0, 'EmployeeNumber': 1, 'EnvironmentSatisfaction': 0, 'Gender': 1, 'HourlyRate': 0, 'JobInvolvement': 0, 'JobLevel': 0, 'JobRole': 1, 'JobSatisfaction': 0, 'MaritalStatus': 1, 'MonthlyRate': 2, 'NumCompaniesWorked': 0, 'Over18': 0, 'OverTime': 0, 'PercentSalaryHike': 1, 'PerformanceRating': 1, 'RelationshipSatisfaction': 0, 'StandardHours': 0, 'StockOptionLevel': 0, 'TotalWorkingYears': 0, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 0, 'YearsAtCompany': 0, 'YearsInCurrentRole': 0, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 0}

# %% [markdown]
# - Drop any row that contains a Null value

# %%
employee_df.dropna(inplace= True)

# %%
# to check we dropped all of the rows that contain null values 

missing_values = {col: employee_df[col].isnull().sum() for col in employee_df.columns}
print("The columns that contain null value:",missing_values)
print ("\nThe total ammount of null values in the data frame:", employee_df.isnull().sum().sum())
# Out:
# The columns that contain null value: {'Age': 0, 'MonthlyIncome': 0, 'Attrition': 0, 'BusinessTravel': 0, 'DailyRate': 0, 'Department': 0, 'DistanceFromHome': 0, 'Education': 0, 'EducationField': 0, 'EmployeeCount': 0, 'EmployeeNumber': 0, 'EnvironmentSatisfaction': 0, 'Gender': 0, 'HourlyRate': 0, 'JobInvolvement': 0, 'JobLevel': 0, 'JobRole': 0, 'JobSatisfaction': 0, 'MaritalStatus': 0, 'MonthlyRate': 0, 'NumCompaniesWorked': 0, 'Over18': 0, 'OverTime': 0, 'PercentSalaryHike': 0, 'PerformanceRating': 0, 'RelationshipSatisfaction': 0, 'StandardHours': 0, 'StockOptionLevel': 0, 'TotalWorkingYears': 0, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 0, 'YearsAtCompany': 0, 'YearsInCurrentRole': 0, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 0}
#
# The total ammount of null values in the data frame: 0

# %% [markdown]
# - Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463

# %%
# we can notice the size of the dataframe by using this code below: 

employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1463 non-null   int64
#  1   MonthlyIncome             1463 non-null   float64
#  2   Attrition                 1463 non-null   object
#  3   BusinessTravel            1463 non-null   object
#  4   DailyRate                 1463 non-null   int64
#  5   Department                1463 non-null   object
#  6   DistanceFromHome          1463 non-null   int64
#  7   Education                 1463 non-null   int64
#  8   EducationField            1463 non-null   object
#  9   EmployeeCount             1463 non-null   int64
#  10  EmployeeNumber            1463 non-null   float64
#  11  EnvironmentSatisfaction   1463 non-null   int64
#  12  Gender                    1463 non-null   object
#  13  HourlyRate                1463 non-null   int64
# ...

# %% [markdown]
# - Let's check if we still have any missing values

# %%
employee_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - Let's explore an alternative (smarter) method to deal with missing values

# %%
missing_values = {col: employee_df[col].isnull().sum() for col in employee_df.columns}
print("The columns that contain null value:",missing_values)
print ("\nThe total ammount of null values in the data frame:", employee_df.isnull().sum().sum())
# Out:
# The columns that contain null value: {'Age': 0, 'MonthlyIncome': 0, 'Attrition': 0, 'BusinessTravel': 0, 'DailyRate': 0, 'Department': 0, 'DistanceFromHome': 0, 'Education': 0, 'EducationField': 0, 'EmployeeCount': 0, 'EmployeeNumber': 0, 'EnvironmentSatisfaction': 0, 'Gender': 0, 'HourlyRate': 0, 'JobInvolvement': 0, 'JobLevel': 0, 'JobRole': 0, 'JobSatisfaction': 0, 'MaritalStatus': 0, 'MonthlyRate': 0, 'NumCompaniesWorked': 0, 'Over18': 0, 'OverTime': 0, 'PercentSalaryHike': 0, 'PerformanceRating': 0, 'RelationshipSatisfaction': 0, 'StandardHours': 0, 'StockOptionLevel': 0, 'TotalWorkingYears': 0, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 0, 'YearsAtCompany': 0, 'YearsInCurrentRole': 0, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 0}
#
# The total ammount of null values in the data frame: 0

# %%
# Fill missing values for numerical columns with the mean
numerical_columns = ['MonthlyIncome', 'MonthlyRate', 'EmployeeNumber', 'PercentSalaryHike', 'PerformanceRating']
for col in numerical_columns:
    if col in employee_df.columns:
        employee_df[col].fillna(employee_df[col].mean(), inplace=True)

# Fill missing values for categorical columns with the mode
categorical_columns = ['Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']
for col in categorical_columns:
    if col in employee_df.columns:
        employee_df[col].fillna(employee_df[col].mode()[0], inplace=True)
# Out:
# C:\Users\Fay\AppData\Local\Temp\ipykernel_54200\2792450821.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employee_df[col].fillna(employee_df[col].mean(), inplace=True)
# C:\Users\Fay\AppData\Local\Temp\ipykernel_54200\2792450821.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# - Let's read the raw data again using Pandas as follows

# %%
employee_df2 = pd.read_csv('Human_Resources.csv').copy()

# %% [markdown]
# - Calculate the average monthly income

# %%
Avg_monthly_income = employee_df2.MonthlyIncome.mean()
print("the average monthly income for the employees is:",Avg_monthly_income)
# Out:
# the average monthly income for the employees is: 6505.155419222904

# %%
employee_df2.sample()
# Out:
#      Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 346   41         6032.0        No  Travel_Rarely        483
#
#                  Department  DistanceFromHome  Education EducationField  \
# 346  Research & Development                 6          3        Medical
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 346              1  ...                         4             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 346                0                  8                      3
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 346                3              5                   4
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 346                       1                     2
#
# [1 rows x 35 columns]

# %% [markdown]
# - You can use Fillna to fill a given column with a certain value

# %%
missing_values = {col: employee_df2[col].isnull().sum() for col in employee_df2.columns}
print("The columns that contain null value:",missing_values)
print ("\nThe total ammount of null values in the data frame:", employee_df2.isnull().sum().sum())
# Out:
# The columns that contain null value: {'Age': 0, 'MonthlyIncome': 3, 'Attrition': 0, 'BusinessTravel': 0, 'DailyRate': 0, 'Department': 1, 'DistanceFromHome': 0, 'Education': 0, 'EducationField': 1, 'EmployeeCount': 0, 'EmployeeNumber': 1, 'EnvironmentSatisfaction': 0, 'Gender': 1, 'HourlyRate': 0, 'JobInvolvement': 0, 'JobLevel': 0, 'JobRole': 1, 'JobSatisfaction': 0, 'MaritalStatus': 1, 'MonthlyRate': 2, 'NumCompaniesWorked': 0, 'Over18': 0, 'OverTime': 0, 'PercentSalaryHike': 1, 'PerformanceRating': 1, 'RelationshipSatisfaction': 0, 'StandardHours': 0, 'StockOptionLevel': 0, 'TotalWorkingYears': 0, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 0, 'YearsAtCompany': 0, 'YearsInCurrentRole': 0, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 0}
#
# The total ammount of null values in the data frame: 13

# %%
employee_df2.PercentSalaryHike.value_counts()
# Out:
# PercentSalaryHike
# 11.0    210
# 13.0    209
# 14.0    201
# 12.0    198
# 15.0    101
# 18.0     89
# 17.0     82
# 16.0     78
# 19.0     76
# 22.0     56
# 20.0     54
# 21.0     48
# 23.0     28
# 24.0     21
# 25.0     18
# Name: count, dtype: int64

# %%
# since there is 3 missing data in monthly income and monthly income is a float and a numerical ----> we will use mean

employee_df2.MonthlyIncome.fillna(employee_df2.MonthlyIncome.mean(),inplace=True)

employee_df2['Monthly_Rate_2']=employee_df2['MonthlyRate']
employee_df2.Monthly_Rate_2.fillna(employee_df2.MonthlyRate.mean(),inplace=True)

employee_df2.PercentSalaryHike.fillna(employee_df2.PercentSalaryHike.mean(),inplace=True)

employee_df2.PerformanceRating.fillna(employee_df2.PerformanceRating.mode()[0],inplace=True)
# Out:
# C:\Users\Fay\AppData\Local\Temp\ipykernel_54200\2947472607.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employee_df2.MonthlyIncome.fillna(employee_df2.MonthlyIncome.mean(),inplace=True)
# C:\Users\Fay\AppData\Local\Temp\ipykernel_54200\2947472607.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
employee_df2.PercentSalaryHike.value_counts()
# Out:
# PercentSalaryHike
# 11.000000    210
# 13.000000    209
# 14.000000    201
# 12.000000    198
# 15.000000    101
# 18.000000     89
# 17.000000     82
# 16.000000     78
# 19.000000     76
# 22.000000     56
# 20.000000     54
# 21.000000     48
# 23.000000     28
# 24.000000     21
# 25.000000     18
# 15.206263      1
# Name: count, dtype: int64

# %%
employee_df2.PercentSalaryHike.isnull().sum()
# Out:
# 0

# %%
missing_values = {col: employee_df2[col].isnull().sum() for col in employee_df2.columns}
print(missing_values)
# Out:
# {'Age': 0, 'MonthlyIncome': 0, 'Attrition': 0, 'BusinessTravel': 0, 'DailyRate': 0, 'Department': 1, 'DistanceFromHome': 0, 'Education': 0, 'EducationField': 1, 'EmployeeCount': 0, 'EmployeeNumber': 1, 'EnvironmentSatisfaction': 0, 'Gender': 1, 'HourlyRate': 0, 'JobInvolvement': 0, 'JobLevel': 0, 'JobRole': 1, 'JobSatisfaction': 0, 'MaritalStatus': 1, 'MonthlyRate': 2, 'NumCompaniesWorked': 0, 'Over18': 0, 'OverTime': 0, 'PercentSalaryHike': 0, 'PerformanceRating': 0, 'RelationshipSatisfaction': 0, 'StandardHours': 0, 'StockOptionLevel': 0, 'TotalWorkingYears': 0, 'TrainingTimesLastYear': 0, 'WorkLifeBalance': 0, 'YearsAtCompany': 0, 'YearsInCurrentRole': 0, 'YearsSinceLastPromotion': 0, 'YearsWithCurrManager': 0, 'Monthly_Rate_2': 0}

# %%
# the department column fill the empty cells

print ("the type of the columns data:",employee_df2.Department.dtype,"\n")
print ('the values of Department before are:',employee_df2.Department.value_counts(),"\n")
print('the null values amount before:',employee_df2.Department.isnull().sum(),"\n")
employee_df2.Department = employee_df2.Department.replace(np.NaN,"unknown")
print ('the values of Department after are:',employee_df2.Department.value_counts(),"\n")
print('the null values amount after:',employee_df2.Department.isnull().sum(),"\n")
# Out:
# the type of the columns data: object
#
# the values of Department before are: Department
# Research & Development    960
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
#
# the null values amount before: 1
#
# the values of Department after are: Department
# Research & Development    960
# Sales                     446
# Human Resources            63
# unknown                     1
# Name: count, dtype: int64
#
# the null values amount after: 0

# %%
# the EducationField column filling the empty cells

print ("the type of the columns data:",employee_df2.EducationField.dtype,"\n")

print ('the values of EducationField before are:\n',employee_df2.EducationField.value_counts(),"\n")

print('the null values amount before:',employee_df2.EducationField.isnull().sum(),"\n")

# replacing the unknown cells with np.nan
employee_df2.EducationField = employee_df2.EducationField.replace(np.NaN,"unknown")
print ('the values of EducationField after are:',employee_df2.EducationField.value_counts(),"\n")

print('the null values amount after:',employee_df2.EducationField.isnull().sum(),"\n")
# Out:
# the type of the columns data: object
#
# the values of EducationField before are:
#  EducationField
# Life Sciences       606
# Medical             463
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
#
# the null values amount before: 1
#
# the values of EducationField after are: EducationField
# Life Sciences       606
# Medical             463
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# unknown               1
# Name: count, dtype: int64
#
# the null values amount after: 0

# %%
# the EmployeeNumber column filling the empty cells

print ("the type of the columns data:",employee_df2.EmployeeNumber.dtype,"\n")

print ('the values of Employee Number before are:',employee_df2.EmployeeNumber.value_counts(),"\n")

print('the null values amount before:',employee_df2.EmployeeNumber.isnull().sum(),"\n")

# changing the - to np.nan
employee_df2.EmployeeNumber = employee_df2.EmployeeNumber.replace(np.NaN,"-")
print ('the values of Employee Number after are:',employee_df2.EmployeeNumber.value_counts(),"\n")

print('the null values amount after:',employee_df2.EmployeeNumber.isnull().sum(),"\n")
# Out:
# the type of the columns data: float64
#
# the values of Employee Number before are: EmployeeNumber
# 1.0       1
# 1392.0    1
# 1390.0    1
# 1389.0    1
# 1387.0    1
#          ..
# 661.0     1
# 659.0     1
# 657.0     1
# 656.0     1
# 2068.0    1
# Name: count, Length: 1469, dtype: int64
#
# the null values amount before: 1
#
# the values of Employee Number after are: EmployeeNumber
# 1.0       1
# 1391.0    1
# 1389.0    1
# 1387.0    1
# 1383.0    1
#          ..
# 659.0     1
# 657.0     1
# 656.0     1
# 655.0     1
# 2068.0    1
# Name: count, Length: 1470, dtype: int64
#
# the null values amount after: 0

# %%
# the Gender column filling the empty cells

print ("the type of the columns data:",employee_df2.Gender.dtype,"\n")

print ('the values of Gender before are:',employee_df2.Gender.value_counts(),"\n")

print('the null values amount before:',employee_df2.Gender.isnull().sum(),"\n")

# replaving the unknown to np.nan
employee_df2.Gender = employee_df2.Gender.replace(np.nan,"unknown")
print ('the values of Gender after are:',employee_df2.Gender.value_counts(),"\n")

print('the null values amount after:',employee_df2.Gender.isnull().sum(),"\n")
# Out:
# the type of the columns data: object
#
# the values of Gender before are: Gender
# Male      882
# Female    587
# Name: count, dtype: int64
#
# the null values amount before: 1
#
# the values of Gender after are: Gender
# Male       882
# Female     587
# unknown      1
# Name: count, dtype: int64
#
# the null values amount after: 0

# %%
# the JobRole column filling the empty cells

print ("the type of the columns data:",employee_df2.JobRole.dtype,"\n")

print ('the values of Job Role before are:',employee_df2.JobRole.value_counts(),"\n")

print('the null values amount before:',employee_df2.JobRole.isnull().sum(),"\n")

# replacing the np.nan to the unknown
employee_df2.JobRole = employee_df2.JobRole.replace(np.nan,"unknown")
print ('the values of Job Role after are:',employee_df2.JobRole.value_counts(),"\n")

print('the null values amount after:',employee_df2.JobRole.isnull().sum(),"\n")
# Out:
# the type of the columns data: object
#
# the values of Job Role before are: JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        258
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
#
# the null values amount before: 1
#
# the values of Job Role after are: JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        258
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# unknown                        1
# Name: count, dtype: int64
#
# the null values amount after: 0

# %%
# the MaritalStatus column filling the empty cells

print ("the type of the columns data:",employee_df2.MaritalStatus.dtype,"\n")

print ('the values of Marital Status before are:',employee_df2.MaritalStatus.value_counts(),"\n")

print('the null values amount before:',employee_df2.MaritalStatus.isnull().sum(),"\n")

#replacing the empty cells / np.nan tp unknown
employee_df2.MaritalStatus = employee_df2.MaritalStatus.replace(np.nan,"unknown")
print ('the values of Job Role after are:',employee_df2.MaritalStatus.value_counts(),"\n")

print('the null values amount after:',employee_df2.MaritalStatus.isnull().sum(),"\n")
# Out:
# the type of the columns data: object
#
# the values of Marital Status before are: MaritalStatus
# Married     673
# Single      470
# Divorced    326
# Name: count, dtype: int64
#
# the null values amount before: 1
#
# the values of Job Role after are: MaritalStatus
# Married     673
# Single      470
# Divorced    326
# unknown       1
# Name: count, dtype: int64
#
# the null values amount after: 0

# %%
employee_df2.isnull().sum().sum()
# Out:
# 2

# %% [markdown]
# Calculating the median monthly rate to fill out missing data.

# %%
employee_df2.MonthlyRate.isnull().sum()
# Out:
# 2

# %%
employee_df2.MonthlyRate.fillna(employee_df2.MonthlyRate.median(),inplace=True)
# Out:
# C:\Users\Fay\AppData\Local\Temp\ipykernel_54200\2000799040.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employee_df2.MonthlyRate.fillna(employee_df2.MonthlyRate.median(),inplace=True)

# %%
employee_df2.MonthlyRate.isnull().sum()
# Out:
# 0

# %% [markdown]
# #### PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %%
from summarytools import dfSummary
dfSummary(hr_df)
# Out:
# C:\Users\Fay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\summarytools\summarytools.py:124: RuntimeWarning: divide by zero encountered in scalar divide
#   stats += f"<br>IQR (CV) : {x.quantile(0.75) - x.quantile(0.25):.1f} ({x.mean()/x.std():.1f})"
# C:\Users\Fay\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\summarytools\summarytools.py:124: RuntimeWarning: divide by zero encountered in scalar divide
#   stats += f"<br>IQR (CV) : {x.quantile(0.75) - x.quantile(0.25):.1f} ({x.mean()/x.std():.1f})"
# <style type="text/css">
# #T_a63ff thead>tr>th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ##### The above function provides a comprehensive summary of the data frame:
# - as it gives the mean, median, range, standard deviation, interquartile range(IQR), Coefficient of variation(cv), and missing values

# %%
print(hr_df[['EnvironmentSatisfaction', 'WorkLifeBalance']].describe())
# Out:
#        EnvironmentSatisfaction  WorkLifeBalance
# count              1470.000000      1470.000000
# mean                  2.721769         2.761224
# std                   1.093082         0.706476
# min                   1.000000         1.000000
# 25%                   2.000000         2.000000
# 50%                   3.000000         3.000000
# 75%                   4.000000         3.000000
# max                   4.000000         4.000000

# %% [markdown]
# **describe():**
# - is used to generate and print a summary of statistical information for the specified columns in the DataFrame
# - it also creates a new data frame containing only these 2 column
# - the insights from this function are:
#
# 1. Both Environment Satisfaction and Work-Life Balance have mean and median values around 3, indicating that, on average, employees are moderately satisfied with their work environment and work-life balance.
# 2. There is more variation in EnvironmentSatisfaction (std = 1.09) compared to WorkLifeBalance (std = 0.71), suggesting that opinions on the work environment are more diverse than opinions on work-life balance.
# 3. The 25th percentile for both metrics is 2, and the 75th percentile is 4 for EnvironmentSatisfaction and 3 for WorkLifeBalance. It shows that most employees rate their satisfaction and work-life balance between 2 and 4.
# 4. The employees at both ends of the satisfaction spectrum for both metrics, with scores ranging from 1 to 4. It indicates a range of experiences and perceptions among employees regarding their work environment and work-life balance.

# %%
print ("The values of monthly income column are:", hr_df['MonthlyIncome'].value_counts)

print ("\nThe values of age column are:", hr_df['Age'].value_counts)

print ("\nThe values of job level column are:", hr_df['JobLevel'].value_counts)
# Out:
# The values of monthly income column are: <bound method IndexOpsMixin.value_counts of 0       5993.0
# 1          NaN
# 2       2090.0
# 3       2909.0
# 4       3468.0
#          ...
# 1465    2571.0
# 1466    9991.0
# 1467    6142.0
# 1468    5390.0
# 1469    4404.0
# Name: MonthlyIncome, Length: 1470, dtype: float64>
#
# The values of age column are: <bound method IndexOpsMixin.value_counts of 0       41
# 1       49
# 2       37
# 3       33
# 4       27
#         ..
# 1465    36
# 1466    39
# 1467    27
# 1468    49
# 1469    34
# Name: Age, Length: 1470, dtype: int64>
#
# The values of job level column are: <bound method IndexOpsMixin.value_counts of 0       2
# 1       2
# 2       1
# 3       1
# 4       1
#        ..
# 1465    2
# 1466    3
# 1467    2
# 1468    2
# 1469    2
# Name: JobLevel, Length: 1470, dtype: int64>

# %%
hr_df['DistanceFromHome'].min()
# Out:
# 1

# %%
hr_df['DistanceFromHome'].max()
# Out:
# 29

# %%
filtered_df = hr_df[(hr_df['MonthlyIncome'] > 8000) & 
    (hr_df['Age'] < 40) &
    (hr_df['JobLevel'] == 3)]

if len(filtered_df) > 0:
    print("Filtered Employees:")
    print(filtered_df)
    
    mean_income = filtered_df['MonthlyIncome'].mean()
    max_age = filtered_df['Age'].max()
    min_age = filtered_df['Age'].min()
    
    #print("\nInsights:")
    print(f"Average Monthly Income: {mean_income}")
    print(f"Youngest Age: {min_age}, Oldest Age: {max_age}")
else:
    print("No employees found that satisfy all criteria.")
# Out:
# Filtered Employees:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 8      38         9526.0        No  Travel_Frequently        216
# 15     29         9980.0        No      Travel_Rarely       1389
# 22     34        11994.0        No      Travel_Rarely        419
# 43     27         8726.0        No  Travel_Frequently        994
# 53     35         9884.0        No         Non-Travel       1097
# ...   ...            ...       ...                ...        ...
# 1430   38        13206.0        No      Travel_Rarely        201
# 1431   32        10422.0        No      Travel_Rarely        801
# 1432   37        13744.0        No      Travel_Rarely        161
# 1450   35         8837.0        No      Travel_Rarely       1146
# 1466   39         9991.0        No      Travel_Rarely        613
#
#                   Department  DistanceFromHome  Education EducationField  \
# 8     Research & Development                23          3  Life Sciences
# ...

# %% [markdown]
# ##### The output from the filtered data gave the following results:
# 1. The employees in this subset are between 27 and 39 years old. This indicates that the dataset captures a relatively young demographic.
# 2. The average monthly income is approximately 10,286.80 units, indicating that this group tends to earn a higher salary than average.
# 3. All employees in this filtered set have "No" for attrition, implying that they are currently employed and have not left the company.
# 4. Majority of the employee's departments (Research & Development, Sales, and Human Resources). This distribution highlights where higher-income younger employees are likely concentrated within the organization.
# 5. Employees have various education levels, with many holding degrees in the Life Sciences, Medical, and Marketing fields. It suggests a diverse educational background, possibly contributing to the higher incomes observed.
# 6. The DistanceFromHome variable indicates varying commuting distances, which might affect work-life balance and job satisfaction. Employees living farther away might have different needs and preferences compared to those living closer to the workplace. and it also shows that the filterd_df condition didn't affect the work distribution from home.

# %%
# This is a describtion of the data between the range was given above
 
age_min = 27
age_max = 39

df = hr_df.loc[(hr_df['Age'] >= age_min) & (hr_df['Age'] <= age_max)]

print("Filtered DataFrame:")
print(df.describe())
# Out:
# Filtered DataFrame:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  786.000000     786.000000   786.000000        786.000000  786.000000
# mean    33.003817    5321.940204   799.938931          9.043257    2.965649
# std      3.508858    3045.685771   407.642830          7.830573    1.014589
# min     27.000000    1052.000000   103.000000          1.000000    1.000000
# 25%     30.000000    2852.250000   461.000000          2.000000    2.000000
# 50%     33.000000    4643.000000   800.000000          7.000000    3.000000
# 75%     36.000000    6645.500000  1157.000000         13.000000    4.000000
# max     39.000000   19431.000000  1498.000000         29.000000    5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count          786.0      786.000000               786.000000  786.000000
# mean             1.0     1033.839695                 2.749364   65.480916
# ...

# %%
high_daily_rate_df = hr_df[hr_df['DailyRate'] >= 1450]
print(high_daily_rate_df)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31     44         6465.0        No      Travel_Rarely       1459
# 52     44         5454.0        No      Travel_Rarely       1488
# 110    51         7484.0        No  Travel_Frequently       1456
# 117    36         9738.0        No  Travel_Frequently       1467
# 155    29         4319.0        No         Non-Travel       1496
# 164    27         2566.0        No         Non-Travel       1450
# 165    50        19926.0        No      Travel_Rarely       1452
# 172    36         2088.0        No  Travel_Frequently       1480
# 213    51        12490.0        No      Travel_Rarely       1469
# 266    31         5582.0        No      Travel_Rarely       1463
# 278    26         6397.0        No  Travel_Frequently       1479
# 302    28         5661.0        No      Travel_Rarely       1476
# 329    47        18300.0        No      Travel_Rarely       1482
# ...

# %%
high_daily_rate_df.BusinessTravel.value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        34
# Travel_Frequently    10
# Non-Travel            6
# Name: count, dtype: int64

# %% [markdown]
# 1. **The Age column:**
# - The age range of the employees from 26 to 60 that satisfies the condition
# - This indicates that both younger and older employees fall within the specified criteria.
#
# 2. **If they are still working in the company:**
# - A majority of the employees in this filtered dataset (43) do not have attrition ('No').
# - Only a small number (7 rows) have attrition ('Yes').
#
# 3. **Business Travel:**
# - Travel_Rarely appears to be the most common category as it is shown in 34 rows, where the frequently is 10 rows and nontravel is only 6

# %% [markdown]
# - What is the combined Daily Rate for all employees with 1450+?

# %%
print('the daily rate for all the employees with more than 1450 is:',high_daily_rate_df.DailyRate.sum())
# Out:
# the daily rate for all the employees with more than 1450 is: 73749

# %% [markdown]
# #### PERFORM BASIC EDA ON BOTH CLASSES
# - It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other

# %%
print ("The data set before deleting 'EmployeeCount', 'Standardhours' and 'Over18': ", hr_df.sample())

hr_df.drop(columns= ['EmployeeCount','StandardHours', 'Over18'],inplace= True)

print ("\nThe data set after deleting 'EmployeeCount', 'Standardhours' and 'Over18': ", hr_df.sample())
# Out:
# The data set before deleting 'EmployeeCount', 'Standardhours' and 'Over18':       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 284   26         4741.0        No  Travel_Frequently        496
#
#                  Department  DistanceFromHome  Education EducationField  \
# 284  Research & Development                11          2        Medical
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 284              1  ...                         3             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 284                1                  5                      3
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 284                3              5                   3
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 284                       3                     3
#
# [1 rows x 35 columns]
#
# ...

# %% [markdown]
# - Let's see how many employees left the company!

# %%
print(hr_df.Attrition.value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
hr_df.drop(columns=['EmployeeNumber'], inplace=True)

# Display the updated DataFrame
print("\nAfter dropping 'EmployeeNumber' as well:")
print(hr_df)
# Out:
# After dropping 'EmployeeNumber' as well:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# ...

# %%
left_count = hr_df[hr_df['Attrition'] == 'Yes'].shape[0]
print(f"Number of employees who left the company: {left_count}")
# Out:
# Number of employees who left the company: 237

# %%
employees_left = hr_df[hr_df['Attrition'] == 'Yes']
print(employees_left)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 14     28         2028.0       Yes      Travel_Rarely        103
# 21     36         3407.0       Yes      Travel_Rarely       1218
# 24     34         2960.0       Yes      Travel_Rarely        699
# ...   ...            ...       ...                ...        ...
# 1438   23         1790.0       Yes  Travel_Frequently        638
# 1442   29         4787.0       Yes      Travel_Rarely       1092
# 1444   56         2339.0       Yes      Travel_Rarely        310
# 1452   50         6728.0       Yes  Travel_Frequently        878
# 1461   50        10854.0       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# ...

# %% [markdown]
# ##### The dataset for the employees who left the company:
# 1. **Age:**
#    - the ages of the employees who left are different in range from 23 to 56
# 2. **Monthly income:**
#    - The Monthly Income for these employees varies significantly, from as low as 1,790 to as high as 10,854.
#    - the general monthly income is from a minimum of 1,009 to a maximum of 19,999.
#    - which means the employees who left the company have a relatively low monthly income, suggesting that salary might be a factor in their decision to leave.

# %%
hr_df_inComp = hr_df[hr_df['Attrition'] == 'No']
print (hr_df_inComp)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1      49            NaN        No  Travel_Frequently        279
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# 6      59            NaN        No      Travel_Rarely       1324
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
hr_df_inComp.DistanceFromHome.min()
# Out:
# 1

# %%
employees_left.DistanceFromHome.min()
# Out:
# 1

# %% [markdown]
# - Generate statistical summary for employees who stayed

# %%
dfSummary(hr_df_inComp)
# Out:
# <style type="text/css">
# #T_922c6 thead>tr>th {
#   text-align: left;
# }
# #T_922c6_row0_col0, #T_922c6_row1_col0, #T_922c6_row2_col0, #T_922c6_row3_col0, #T_922c6_row4_col0, #T_922c6_row5_col0, #T_922c6_row6_col0, #T_922c6_row7_col0, #T_922c6_row8_col0, #T_922c6_row9_col0, #T_922c6_row10_col0, #T_922c6_row11_col0, #T_922c6_row12_col0, #T_922c6_row13_col0, #T_922c6_row14_col0, #T_922c6_row15_col0, #T_922c6_row16_col0, #T_922c6_row17_col0, #T_922c6_row18_col0, #T_922c6_row19_col0, #T_922c6_row20_col0, #T_922c6_row21_col0, #T_922c6_row22_col0, #T_922c6_row23_col0, #T_922c6_row24_col0, #T_922c6_row25_col0, #T_922c6_row26_col0, #T_922c6_row27_col0, #T_922c6_row28_col0, #T_922c6_row29_col0, #T_922c6_row30_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# ...

# %% [markdown]
# ##### a competent between employees who stayed and left the company:
# 1. **Age:**
#    - Stayed: Age ranges from 27 to 59 years.
#    - Left: Age ranges from 23 to 56 years.
# - this shows even though they have a wide range the employees who left are on average younger than those who stayed.
# 1. **Monthly Income:**
#    - Stayed: Monthly income ranges from 2,571 to 9,991 units, with some missing values (NaN).
#    - Left: Monthly income ranges from 1,790 to 10,854 units.
# - Both groups have a wide range of income. Employees who left have slightly lower starting incomes but also include higher-income employees. It indicates that income alone may not be a main factor in attrition.
#
# **As its shown below**

# %%
summary_left = hr_df.describe()
summary_stayed = hr_df_inComp.describe()

print("Statistical Summary of Employees Who Left:",summary_left)
print("\nStatistical Summary of Employees Who Stayed:",summary_stayed)
# Out:
# Statistical Summary of Employees Who Left:                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1470.000000  1470.000000     1470.000000  1470.000000
# mean                  2.721769    65.891156        2.729932     2.063946
# ...

# %%
# Example of comparing summaries and making inferences
print("Comparison of Average Age:")
print(f"Employees Who Left: {summary_left['Age']['mean']}")
print(f"Employees Who Stayed: {summary_stayed['Age']['mean']}")

print("\nComparison of Average Monthly Income:")
print(f"Employees Who Left: {summary_left['MonthlyIncome']['mean']}")
print(f"Employees Who Stayed: {summary_stayed['MonthlyIncome']['mean']}")

# Example Inferences
if summary_left['Age']['mean'] > summary_stayed['Age']['mean']:
    print("\nInference: Older employees might be more likely to leave the company.")
else:
    print("\nInference: Younger employees might be more likely to leave the company.")

if summary_left['MonthlyIncome']['mean'] < summary_stayed['MonthlyIncome']['mean']:
    print("Inference: Employees with lower monthly income might be more likely to leave the company.")
else:
    print("Inference: Employees with higher monthly income might be more likely to leave the company.")
# Out:
# Comparison of Average Age:
# Employees Who Left: 36.923809523809524
# Employees Who Stayed: 37.561232765612324
#
# Comparison of Average Monthly Income:
# Employees Who Left: 6505.155419222904
# Employees Who Stayed: 6837.504467912267
#
# Inference: Younger employees might be more likely to leave the company.
# Inference: Employees with lower monthly income might be more likely to leave the company.

# %% [markdown]
# #### PANDAS WITH FUNCTIONS
# - Let's assume the daily rate has increased by 10%

# %%
hr_df2 = pd.read_csv('Human_Resources.csv')
hr_df2
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
hr_df2['ten_per'] = hr_df2['DailyRate'] * 0.10
print(hr_df2['ten_per'])

# This helps in understanding the value of a 10% increase in daily rates for each employee.
# Out:
# 0       110.2
# 1        27.9
# 2       137.3
# 3       139.2
# 4        59.1
#         ...
# 1465     88.4
# 1466     61.3
# 1467     15.5
# 1468    102.3
# 1469     62.8
# Name: ten_per, Length: 1470, dtype: float64

# %%
print ("the daily rate before the 10 increase: ",hr_df2['DailyRate'])

hr_df2['DailyRate'] = hr_df2['DailyRate'] + hr_df2['ten_per']

print ("\nthe daily rate after the 10 increase: ",hr_df2['DailyRate'])

# It shows how the daily rates change after a 10% increase, which can be used for financial planning and budgeting.
# Out:
# the daily rate before the 10 increase:  0       1102
# 1        279
# 2       1373
# 3       1392
# 4        591
#         ...
# 1465     884
# 1466     613
# 1467     155
# 1468    1023
# 1469     628
# Name: DailyRate, Length: 1470, dtype: int64
#
# the daily rate after the 10 increase:  0       1212.2
# 1        306.9
# 2       1510.3
# 3       1531.2
# 4        650.1
#          ...
# 1465     972.4
# 1466     674.3
# 1467     170.5
# 1468    1125.3
# 1469     690.8
# Name: DailyRate, Length: 1470, dtype: float64

# %%
hr_df2['Net_Worth'] = hr_df2['MonthlyIncome'] * 12

# This gives a yearly financial perspective of each employee's earnings.

def increase_net_worth(df, net_worth_column, increase_percent= 0.10):

    df[net_worth_column] = df[net_worth_column] * (1 + increase_percent)
    return df

# This provides a flexible way to apply percentage-based increases to any financial column in the DataFrame.

hr_df2 = increase_net_worth(hr_df2, 'Net_Worth')

print(hr_df2['Net_Worth'])

# It shows how the annual net worth of employees changes with a 10% increase, which is useful for scenarios like salary negotiations or financial projections.
# Out:
# 0        79107.6
# 1            NaN
# 2        27588.0
# 3        38398.8
# 4        45777.6
#           ...
# 1465     33937.2
# 1466    131881.2
# 1467     81074.4
# 1468     71148.0
# 1469     58132.8
# Name: Net_Worth, Length: 1470, dtype: float64

# %% [markdown]
# ##### The summary:
# 1. The calculations show how a 10% increase in daily rate and net worth affects employees differently based on their initial salaries.
# 2. The column net_worth reflects each employee’s annual net worth after the 10% increase in their monthly income. It highlights the annualized effect of the salary adjustments. It is useful for understanding long-term financial impacts and for making compensation-related decisions.

# %% [markdown]
# - Defining a function that doubles the DailyRate and adds $100
# - Applying the function to the DataFrame
# - Calculating the updated total Daily Rate of all employees combined

# %%
hr_df2['double_DailyRate'] = hr_df2['DailyRate'] * 2

# Define a function to increase net worth by 10%
def increase_Dailt_Rate(df, double_DailyRate_column, increase_value= 100):
    df[double_DailyRate_column] = df[double_DailyRate_column]+ increase_value
    return df

print('the Daily rate of the employee before:',hr_df2['DailyRate'].head())

hr_df2 = increase_net_worth(hr_df2, 'double_DailyRate')

# Display the DataFrame with the new 'Net_Worth' column
print('\nthe Daily Rate of the employee after doubling it and adding $100',hr_df2['double_DailyRate'].head())

print('\nthe total Daily Rate of all employee after doubling it and adding $100:',hr_df2['double_DailyRate'].sum())
# Out:
# the Daily rate of the employee before: 0    1212.2
# 1     306.9
# 2    1510.3
# 3    1531.2
# 4     650.1
# Name: DailyRate, dtype: float64
#
# the Daily Rate of the employee after doubling it and adding $100 0    2666.84
# 1     675.18
# 2    3322.66
# 3    3368.64
# 4    1430.22
# Name: double_DailyRate, dtype: float64
#
# the total Daily Rate of all employee after doubling it and adding $100: 2854762.6800000006

# %% [markdown]
# #### HISTOGRAM AND CORRELATION
# - Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy as shown below

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(hr_df2['MonthlyIncome'], bins=20, edgecolor='black')
plt.title('Histogram of MonthlyIncome')
plt.xlabel('MonthlyIncome')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(hr_df2['TotalWorkingYears'], bins=20, edgecolor='black')
plt.title('Histogram of TotalWorkingYears')
plt.xlabel('TotalWorkingYears')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Insights from the output:
# - The figure are tail heavy or positive skew it indicates that while most employees earn a lower monthly income, a few earn significantly higher amounts.

# %% [markdown]
# - Job level is strongly correlated with total working hours

# %%
correlation = hr_df2['JobLevel'].corr(hr_df2['TotalWorkingYears'])

print(f"Correlation between JobLevel and TotalWorkingYears: {correlation}")

# Visualize the relationship using a scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='JobLevel', y='TotalWorkingYears', data=hr_df2, scatter_kws={'s': 100})
plt.title('Relationship between JobLevel and TotalWorkingYears')
plt.xlabel('JobLevel')
plt.ylabel('TotalWorkingYears')
plt.grid(True)
plt.show()
# Out:
# Correlation between JobLevel and TotalWorkingYears: 0.7822078045362734

# %% [markdown]
# - Monthly income is strongly correlated with Job level

# %%
hr_df2.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'ten_per', 'Net_Worth', 'double_DailyRate'],
#       dtype='object')

# %%
correlation = hr_df2['MonthlyIncome'].corr(hr_df2['JobLevel'])

print(f"Correlation between MonthlyIncome and JobLevel: {correlation}")

# Visualize the relationship using a scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='JobLevel', y='MonthlyIncome', data=hr_df2, scatter_kws={'s': 100})
plt.title('Relationship between MonthlyIncome and JobLevel')
plt.xlabel('JobLevel')
plt.ylabel('MonthlyIncome')
plt.grid(True)
plt.show()
# Out:
# Correlation between MonthlyIncome and JobLevel: 0.9503464837020152

# %% [markdown]
# - Monthly income is strongly correlated with total working hours

# %%
hr_df2['TotalWorkingHours'] = hr_df2['TotalWorkingYears'] + hr_df2['YearsAtCompany']

# Display the DataFrame with total working hours
print(hr_df2['TotalWorkingHours'])
# Out:
# 0       14
# 1       20
# 2        7
# 3       16
# 4        8
#         ..
# 1465    22
# 1466    16
# 1467    12
# 1468    26
# 1469    10
# Name: TotalWorkingHours, Length: 1470, dtype: int64

# %%
correlation = hr_df2['MonthlyIncome'].corr(hr_df2['TotalWorkingHours'])

print(f"Correlation between Monthly Income and Total Working Hours:\n {correlation}")

# Visualize the relationship using a scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='JobLevel', y='TotalWorkingHours', data=hr_df2, scatter_kws={'s': 100})
plt.title('Relationship between Monthly Income and Total Working Hours')
plt.xlabel('TotalWorkingHours')
plt.ylabel('WorkingHours')
plt.grid(True)
plt.show();
# Out:
# Correlation between Monthly Income and Total Working Hours:
#  0.729257035985493

# %%
correlation = hr_df2['Age'].corr(hr_df2['MonthlyIncome'])

print(f"Correlation between Age and MonthlyIncome: {correlation}")

# Visualize the relationship using a scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Age', y='MonthlyIncome', data=hr_df2, scatter_kws={'s': 100})
plt.title('Relationship between Age and MonthlyIncome')
plt.xlabel('Age')
plt.ylabel('MonthlyIncome')
plt.grid(True)
plt.show()
# Out:
# Correlation between Age and MonthlyIncome: 0.5009148441433067

# %% [markdown]
# we can also change the color for the correlation and use it in a heatmap

# %%
numerical_columns = hr_df.select_dtypes(include=['float64', 'int64']).columns

correlation_matrix = hr_df[numerical_columns].corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
